# %%
from data_utils import load_data
from hybrid_model import build_bi_cnn_banet_model,build_bi_cnn_banet_angle_model
from model_utils import model_pipeline,plot_history
import numpy as np

# %%
train_participant_num = ["C56D","C93D","C382D","C382N","C544D","C709N","C788N","P113D","P113N","P191D","P191N","P299D","P299N","P300D","P336D","P492D","P492N","P531N","P699D","P699N","P890N","P921D","P921N"]
valid_participant_num = ["C67D","C202D","C202N","C256D","C256N","P54D","P54N","P342D","P342N","P487D","P487N","P649N"]

# %%
X_train, y_train = load_data(train_participant_num, 'train', downsampling=True,angle_energy=False,augment=False)
X_valid, y_valid = load_data(valid_participant_num, 'validation')
# Out:
# C56D is not selected to be used for training (downsampling)
# C93D is not selected to be used for training (downsampling)
# C382D is not selected to be used for training (downsampling)
# C382N is not selected to be used for training (downsampling)
# C544D is not selected to be used for training (downsampling)
# C709N is not selected to be used for training (downsampling)
# C788N is not selected to be used for training (downsampling)
# P113D is selected to be used for training (downsampling)
# P113N is selected to be used for training (downsampling)
# P191D is selected to be used for training (downsampling)
# P191N is selected to be used for training (downsampling)
# P299D is selected to be used for training (downsampling)
# P299N is selected to be used for training (downsampling)
# P300D is selected to be used for training (downsampling)
# P336D is selected to be used for training (downsampling)
# P492D is selected to be used for training (downsampling)
# P492N is selected to be used for training (downsampling)
# P531N is selected to be used for training (downsampling)
# P699D is selected to be used for training (downsampling)
# P699N is selected to be used for training (downsampling)
# P890N is selected to be used for training (downsampling)
# P921D is selected to be used for training (downsampling)
# P921N is selected to be used for training (downsampling)

# %%
print(X_train.shape,np.unique(y_train[:,0],return_counts=True))

print(X_valid.shape,np.unique(y_valid[:,0],return_counts=True))
# Out:
# (5012, 180, 70) (array([0., 1.], dtype=float32), array([1053, 3959]))
# (2869, 180, 70) (array([0., 1.], dtype=float32), array([ 171, 2698]))

# %%
model = build_bi_cnn_banet_model()
y_pred, y_true, H = model_pipeline(model, X_train, y_train, X_valid, y_valid,epoch=30)
plot_history(H)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/30
# 11/11 [==============================] - 21s 1s/step - loss: 0.1484 - binary_accuracy: 0.7392 - val_loss: 0.1620 - val_binary_accuracy: 0.7567 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.1274 - binary_accuracy: 0.7919 - val_loss: 0.1047 - val_binary_accuracy: 0.9261 - lr: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.1219 - binary_accuracy: 0.8069 - val_loss: 0.0821 - val_binary_accuracy: 0.9407 - lr: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.1176 - binary_accuracy: 0.8148 - val_loss: 0.0717 - val_binary_accuracy: 0.9425 - lr: 0.0010
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/30
# 11/11 [==============================] - 16s 1s/step - loss: 0.1152 - binary_accuracy: 0.8160 - val_loss: 0.0690 - val_binary_accuracy: 0.9421 - lr: 0.0010
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 6/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.1135 - binary_accuracy: 0.8202 - val_loss: 0.0655 - val_binary_accuracy: 0.9418 - lr: 0.0010
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 7/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.1109 - binary_accuracy: 0.8236 - val_loss: 0.0625 - val_binary_accuracy: 0.9418 - lr: 0.0010
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 8/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.1094 - binary_accuracy: 0.8222 - val_loss: 0.0638 - val_binary_accuracy: 0.9428 - lr: 0.0010
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 9/30
# 11/11 [==============================] - 16s 1s/step - loss: 0.1078 - binary_accuracy: 0.8258 - val_loss: 0.0592 - val_binary_accuracy: 0.9432 - lr: 0.0010
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 10/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.1057 - binary_accuracy: 0.8286 - val_loss: 0.0610 - val_binary_accuracy: 0.9442 - lr: 0.0010
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0009500000451225787.
# Epoch 11/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.1041 - binary_accuracy: 0.8338 - val_loss: 0.0583 - val_binary_accuracy: 0.9428 - lr: 9.5000e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0009025000152178108.
# Epoch 12/30
# 11/11 [==============================] - 16s 1s/step - loss: 0.1022 - binary_accuracy: 0.8350 - val_loss: 0.0623 - val_binary_accuracy: 0.9456 - lr: 9.0250e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0008573750033974647.
# Epoch 13/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.1016 - binary_accuracy: 0.8348 - val_loss: 0.0608 - val_binary_accuracy: 0.9425 - lr: 8.5737e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0008145062311086804.
# Epoch 14/30
# 11/11 [==============================] - 17s 2s/step - loss: 0.0990 - binary_accuracy: 0.8366 - val_loss: 0.0642 - val_binary_accuracy: 0.9418 - lr: 8.1451e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0007737808919046074.
# Epoch 15/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.0989 - binary_accuracy: 0.8378 - val_loss: 0.0576 - val_binary_accuracy: 0.9407 - lr: 7.7378e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.000735091819660738.
# Epoch 16/30
# 11/11 [==============================] - 16s 1s/step - loss: 0.0971 - binary_accuracy: 0.8428 - val_loss: 0.0653 - val_binary_accuracy: 0.9327 - lr: 7.3509e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0006983372120885178.
# Epoch 17/30
# 11/11 [==============================] - 16s 1s/step - loss: 0.0957 - binary_accuracy: 0.8444 - val_loss: 0.0658 - val_binary_accuracy: 0.9303 - lr: 6.9834e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0006634203542489559.
# Epoch 18/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.0949 - binary_accuracy: 0.8470 - val_loss: 0.0696 - val_binary_accuracy: 0.9233 - lr: 6.6342e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0006302493420662358.
# Epoch 19/30
# 11/11 [==============================] - 16s 1s/step - loss: 0.0928 - binary_accuracy: 0.8490 - val_loss: 0.0720 - val_binary_accuracy: 0.9198 - lr: 6.3025e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0005987368611386045.
# Epoch 20/30
# 11/11 [==============================] - 16s 1s/step - loss: 0.0922 - binary_accuracy: 0.8520 - val_loss: 0.0774 - val_binary_accuracy: 0.9003 - lr: 5.9874e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0005688000208465382.
# Epoch 21/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.0900 - binary_accuracy: 0.8573 - val_loss: 0.0823 - val_binary_accuracy: 0.8906 - lr: 5.6880e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0005403600225690752.
# Epoch 22/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.0889 - binary_accuracy: 0.8538 - val_loss: 0.0792 - val_binary_accuracy: 0.8930 - lr: 5.4036e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0005133419937919825.
# Epoch 23/30
# 11/11 [==============================] - 16s 1s/step - loss: 0.0878 - binary_accuracy: 0.8611 - val_loss: 0.0827 - val_binary_accuracy: 0.8867 - lr: 5.1334e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0004876748775132.
# Epoch 24/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.0870 - binary_accuracy: 0.8605 - val_loss: 0.0864 - val_binary_accuracy: 0.8843 - lr: 4.8767e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.00046329112810781223.
# Epoch 25/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.0856 - binary_accuracy: 0.8599 - val_loss: 0.0884 - val_binary_accuracy: 0.8794 - lr: 4.6329e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.00044012657308485355.
# Epoch 26/30
# 11/11 [==============================] - 16s 1s/step - loss: 0.0851 - binary_accuracy: 0.8651 - val_loss: 0.0916 - val_binary_accuracy: 0.8784 - lr: 4.4013e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.00041812024719547477.
# Epoch 27/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.0842 - binary_accuracy: 0.8647 - val_loss: 0.0903 - val_binary_accuracy: 0.8804 - lr: 4.1812e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00039721422654110934.
# Epoch 28/30
# 11/11 [==============================] - 16s 1s/step - loss: 0.0830 - binary_accuracy: 0.8639 - val_loss: 0.0899 - val_binary_accuracy: 0.8770 - lr: 3.9721e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.00037735351797891776.
# Epoch 29/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.0824 - binary_accuracy: 0.8661 - val_loss: 0.0942 - val_binary_accuracy: 0.8728 - lr: 3.7735e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.00035848583793267607.
# Epoch 30/30
# 11/11 [==============================] - 15s 1s/step - loss: 0.0818 - binary_accuracy: 0.8691 - val_loss: 0.0904 - val_binary_accuracy: 0.8763 - lr: 3.5849e-04
# 90/90 [==============================] - 3s 29ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93      2698
#            1       0.29      0.71      0.41       171
#
#     accuracy                           0.88      2869
#    macro avg       0.63      0.80      0.67      2869
# weighted avg       0.94      0.88      0.90      2869
#
# Confusion matrix:
# [[2392  306]
#  [  49  122]]
